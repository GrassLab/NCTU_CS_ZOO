# %% [markdown]
# # HW 4: 從虛擬世界走向真實世界——自駕車燈號與車輪控制 (數位電路設計)
# 2020.10.23

# %% [markdown]
# ## Tutorial
#
# - [作業講解（螢幕錄影）](https://youtu.be/ulPMo5kLa8g)
# - [作業講解（投影片）](https://hackmd.io/@ierosodin/BkRq6J0LD)
# - [Representing Numbers and Letters with Binary](https://www.youtube.com/watch?v=1GSjbWt0c9M&t=546s)
# - [Boolean Logic & Logic Gates](https://www.youtube.com/watch?v=gI-qXk7XojA)
# - [Truth Tables](https://www.youtube.com/watch?v=_Lb2c18xdeo&ab_channel=WilliamSpaniel)
# - [Encoders and Decoders](https://www.youtube.com/watch?v=RH2SeKV_DKg&ab_channel=NTS)

# %% [markdown]
# ## Objective
#
# - 學習基本電路
# - 了解邏輯閘與真值表
# - 實作簡單的組合邏輯電路

# %% [markdown]
# ## Requirement
#
# - 利用邏輯閘，實作出 2 to 4 的 one hot decoder，以透過 2 顆按鈕控制 4 顆輸出 LED 燈的亮暗

# %% [markdown]
# - 2 to 4 one hot decoder 的真值表
#
# | In1 | In2 | Out1 | Out2 | Out3 | Out4 |
# | :-- | :-- | :--- | :--- | :--- | :--- |
# | F | F | F | F | F | T |
# | F | T | F | F | T | F |
# | T | F | F | T | F | F |
# | T | T | T | F | F | F |

# %% [markdown]
# ### Step 1
#
# - 參考上方的真值表，利用數種邏輯閘的搭配組合，**完成下方的電路圖**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Step 2
#
# - 在麵包板上，透過相對應的電子元件，實作出 Step1 電路
#
#
#  | SN74LS08N (AND) | SN74LS32N (OR) |
#  | :-------------: | :------------: |
#  | ![](https://i.imgur.com/GpoWU7m.png) | ![](https://i.imgur.com/Z9KYCHE.png) |
#
#
#  | SN74LS04N (NOT) | SN74LS00N (NAND) |
#  | :-------------: | :--------------: |
#  | ![](https://i.imgur.com/1DCUUrB.png) | ![](https://i.imgur.com/teFUWPt.png) |
#
#
#  | SN74LS02N (NOR) | SN74LS86N (XOR) |
#  | :-------------: | :-------------: |
#  | ![](https://i.imgur.com/hMRq4jN.png) | ![](https://i.imgur.com/VDSnOL0.png) |

# %% [markdown]
# ## Step 3
#
# - 在 Step 2 的電路上，接上輸入端的按鈕以及輸出端的 LED 燈
# - 參考電路
#     <img src="data:image/png;base64,..." alt="image.png"/>

# %% [markdown]
# ## Reference
# - [NAND gate | a Minimal Set of Universal Gate](https://www.youtube.com/watch?v=okZBqPd1xd4&t=54s&ab_channel=PracticalNinjas)
# - [NOR gate | a Minimal Set of Universal Gate](https://www.youtube.com/watch?v=auh8NRN0wR0&t=100s&ab_channel=PracticalNinjas)
# - [What is Half Adder](https://www.youtube.com/watch?v=thkTzdnkL5U&ab_channel=PracticalNinjas)
# - [Pull-up and Pull-down Resistors](https://www.youtube.com/watch?v=aPVMKyZpaPA&t=400s&ab_channel=BenFinio)
# - [Introduction to Karnaugh Maps - Combinational Logic Circuits, Functions, & Truth Tables](https://www.youtube.com/watch?v=RO5alU6PpSU)
# - [Multiplexers and Decoders](https://www.youtube.com/watch?v=HU31Wh-4_K8)
# - [Digital Electronics](https://www.youtube.com/watch?v=cdMJvFT-Afc (8:45))
